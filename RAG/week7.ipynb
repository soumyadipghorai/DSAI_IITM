# %%
import langchain
from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter

import os
from google.colab import userdata
from openai import OpenAI
from IPython.display import Markdown, display

# %%
from langchain_groq import ChatGroq
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

llm = ChatGroq(model_name = 'openai/gpt-oss-120b', temperature = 0.7)
display(Markdown(llm.invoke('what is the capital of India').content))
# Out:
# The capital of India is **New Delhi**.

# %%
doc1 = Document(
    page_content = 'this is the first document',
    metadata = {'source' : 'file1.txt'}
)

# %%
doc1.page_content
# Out:
# 'this is the first document'

# %%
loader = TextLoader('rag_text.txt')
docs2 = loader.load()
# docs2 ==> list

# %%
for doc in docs2:
    print(doc.page_content, doc.metadata)
# Out:
# Privacy and Security in Online Social Media
# Week -10 Assignment (Graded)
# Maximum Marks = 30 (+6 bonus)
# 1. [3 marks] What is the 3R strategy to conduct ethical studies according to the Principles of
# Humane Experimental Technique (Russell and Burch, 1959)?
# 2. [1 mark] What strategy can be used to determine the required sample size for a survey
# design?
# 3. [3 marks] What are the three principles of research with human subjects and mention how
# they are implemented.
# 4. [2 marks] Mention two instances of research data which were deanonymized soon after
# they were released publicly.
# 5. [2+2 marks] What were the major issues with the FB Emotional Contagion study?
# Suggest ways to modify the experiment such that such issues can be mitigated.
# 6. [1 mark] The density histogram of the number of questions answered by OkCupid users
# follows a _____ distribution
# 7. [3 marks] Draw the scope of considerations needed in data utilization and briefly explain
# each level according to the “Good Data” report by the World Economic Forum.
# 8. [2 marks] In the FB Emotional Contagion experiment, people in the positivity-reduced
# group used _____ positive words and ______ negative words relative to the control group
# 9. [2 marks] What are the three types of validity in social data research?
# 10. [1 mark] Consider an experiment where a researcher measures the anxiety level of users
# based on a questionnaire. Sometime later, the researcher realizes that the questionnaire
# does not accurately measure anxiety levels. What type of research validity is violated in
# this case?
# 11. [3 marks] What are the three types of bias that arise during social data collection? {'source': 'rag_text.txt'}

# %%
loader = PyPDFLoader('rag_doc.pdf')
docs3 = loader.load()
for doc in docs3:
    print(doc.page_content, doc.metadata)
# Out:
# Privacy and Security in Online Social MediaWeek -5 Assignment (Graded Solutions)
# Total Marks: 20
# 1. [2 Marks] What different kinds of analysis can be performed fromthe curatedsocial media data?2. [1 Mark] Name a crowd-sourced method launched by Twitter to fightmisinformation.3. [2Marks]Whatistheissuewiththecrowd-sourcedmethodlaunchedbyTwittertofight misinformation?4. [2Marks]Nametwocategoriesoftextfeaturesthatcanbeextractedfortext-basedfake news detection.5. [2 Marks] What are lexico-syntactic features? Give examples.6. [3 Marks] Please name any one system designed to fight fake news:a. Facebookb. WhatsAppc. Twitter7. [2Marks] MyfriendsentamessagetoourBSWhatsAppgroup.Afterreadingthecontent, I was unsureabouttheveracityofthemessage.NametheserviceIshoulduse to evaluate the message for me. How does that service work?8. [2 Marks] What novel characteristics does the following multi-modal fake newsdetection method comprise:a. Event Adversarial Neural Networks for Multimodal Fake News Detectionb. Multimodal Variational Autoencoder for Fake News Detection9. [2 Marks] Name two events discussed in the lecture affected by fake newsdissemination.10.[2 Marks] Mark if the statement is True/False. Give reasons.FakeURLspreadspikes at 10hours after the introductionof theURLs inthe Twitter network {'producer': 'Skia/PDF m113 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'week-5-graded (1).docx', 'source': 'rag_doc.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# Answers
# 1. Content Analysis, User network Analysis and Temporal Patterns2. Birdwatch3. TheBirdwatchsystemcanbevulnerabletomalicious actors. Suchactors canaddfake ratings to notes to increase or decrease its perceived quality, andconsequently, the classification of the tweet4. Generic text features  and Latent text features5. Combination of Lexical +syntactic features. The lexical features are unigrams,bigrams etc, while the syntactic features can be part of speech tags and so on6. The answer is as follows:a. Facebook: FBI Inspectorb. WhatsApp: WhatsFarzic. Twitter: TweetCred7. Tipline. AtiplinewouldbeaphonenumbertowhichWhatsAppuserscanforwardinformation they see in order to have it evaluated by fact checkers 8. The answer is as follows:a. Event Adversarial Neural Networks for Multimodal FakeNews Detection:removes the event-specific features and keep shared features among eventsb. Multimodal Variational Autoencoder for Fake News Detection: discoverscorrelations across modalities9. Hurricane Sandy, Boston Marathon10.False. 12 hours {'producer': 'Skia/PDF m113 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'week-5-graded (1).docx', 'source': 'rag_doc.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 75, chunk_overlap = 15)
chunks = splitter.split_documents(docs2)
for chunk in chunks:
    print(chunk.page_content)
# Out:
# Privacy and Security in Online Social Media
# Week -10 Assignment (Graded)
# Maximum Marks = 30 (+6 bonus)
# 1. [3 marks] What is the 3R strategy to conduct ethical studies according
# according to the Principles of
# Humane Experimental Technique (Russell and Burch, 1959)?
# 2. [1 mark] What strategy can be used to determine the required sample
# sample size for a survey
# design?
# 3. [3 marks] What are the three principles of research with human subjects
# human subjects and mention how
# they are implemented.
# 4. [2 marks] Mention two instances of research data which were
# which were deanonymized soon after
# they were released publicly.
# 5. [2+2 marks] What were the major issues with the FB Emotional Contagion
# Contagion study?
# Suggest ways to modify the experiment such that such issues can be
# issues can be mitigated.
# 6. [1 mark] The density histogram of the number of questions answered by
# answered by OkCupid users
# follows a _____ distribution
# 7. [3 marks] Draw the scope of considerations needed in data utilization
# utilization and briefly explain
# each level according to the “Good Data” report by the World Economic
# World Economic Forum.
# 8. [2 marks] In the FB Emotional Contagion experiment, people in the
# people in the positivity-reduced
# group used _____ positive words and ______ negative words relative to the
# to the control group
# 9. [2 marks] What are the three types of validity in social data research?
# data research?
# 10. [1 mark] Consider an experiment where a researcher measures the
# measures the anxiety level of users
# based on a questionnaire. Sometime later, the researcher realizes that the
# that the questionnaire
# does not accurately measure anxiety levels. What type of research validity
# validity is violated in
# this case?
# 11. [3 marks] What are the three types of bias that arise during social
# during social data collection?

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

vectors = embeddings.embed_documents([doc.page_content for doc in chunks])
print(len(vectors), len(vectors[0]))
# Out:
# 40 3072

# %%
vectorstore = FAISS.from_documents(chunks, embeddings)

# %%
all_docs = vectorstore.docstore._dict

for doc_id, doc in all_docs.items():
    print(doc_id, doc.page_content, doc.metadata)
# Out:
# 83fbf558-9bc9-4c00-964d-63be8bda7c25 Privacy and Security in Online Social Media
# Week -10 Assignment (Graded) {'source': 'rag_text.txt'}
# 7752df01-d7f5-4bd8-af57-542d06ed84fe Maximum Marks = 30 (+6 bonus) {'source': 'rag_text.txt'}
# 3149b05a-d231-43e4-906c-c5e24dd68067 1. [3 marks] What is the 3R strategy to conduct ethical studies according {'source': 'rag_text.txt'}
# 08c64fd2-25c4-4970-b38b-bac35ce0f489 according to the Principles of {'source': 'rag_text.txt'}
# 65d8eb6b-c0eb-4c74-aa28-e0b671b154cb Humane Experimental Technique (Russell and Burch, 1959)? {'source': 'rag_text.txt'}
# a5f4cd6c-c17b-497d-96b3-eaa9e4c02961 2. [1 mark] What strategy can be used to determine the required sample {'source': 'rag_text.txt'}
# 4752c77c-08c9-47b9-aa85-68219f125cda sample size for a survey {'source': 'rag_text.txt'}
# 452733d3-f234-4c6f-a042-faca86a6cca6 design? {'source': 'rag_text.txt'}
# 15ed8f5a-690b-45b1-a595-879824ecef4f 3. [3 marks] What are the three principles of research with human subjects {'source': 'rag_text.txt'}
# 5c90a2fd-2408-45d5-9611-dbc2dd55d8ee human subjects and mention how {'source': 'rag_text.txt'}
# 6c92311c-9167-4c9c-931a-0fb1978e9311 they are implemented. {'source': 'rag_text.txt'}
# cb3045f8-faa7-4ff3-8ca1-22becc1ee32c 4. [2 marks] Mention two instances of research data which were {'source': 'rag_text.txt'}
# a75768c8-f632-486b-9f10-aa9502232acf which were deanonymized soon after {'source': 'rag_text.txt'}
# 1bd3d6c8-33d2-40b0-9f2d-9b0caaa24092 they were released publicly. {'source': 'rag_text.txt'}
# a77546ed-ab29-4eed-9f48-5b2716836579 5. [2+2 marks] What were the major issues with the FB Emotional Contagion {'source': 'rag_text.txt'}
# c8554897-80f1-4434-bc40-dd7f5275a441 Contagion study? {'source': 'rag_text.txt'}
# c8f63b2c-a34a-4e62-8c88-9c25ecc1bd89 Suggest ways to modify the experiment such that such issues can be {'source': 'rag_text.txt'}
# 0a806e65-88b2-4fec-bda5-dfaa76b224a8 issues can be mitigated. {'source': 'rag_text.txt'}
# 872f24ac-4dac-441e-8182-9ce83790d3b6 6. [1 mark] The density histogram of the number of questions answered by {'source': 'rag_text.txt'}
# e1ebe165-ddba-4591-b014-a0f8fee5e632 answered by OkCupid users {'source': 'rag_text.txt'}
# 09432c3b-b258-49d6-bb5e-63b9d9722d3e follows a _____ distribution {'source': 'rag_text.txt'}
# 049cc073-4615-470c-8aa3-c1305f25aa8a 7. [3 marks] Draw the scope of considerations needed in data utilization {'source': 'rag_text.txt'}
# a400ac37-ce02-44f3-a461-da000476bf96 utilization and briefly explain {'source': 'rag_text.txt'}
# c0b5839b-c4c1-47aa-8fb2-acbb13d55987 each level according to the “Good Data” report by the World Economic {'source': 'rag_text.txt'}
# 1986e210-5538-4178-94ac-34c21dfb150a World Economic Forum. {'source': 'rag_text.txt'}
# 5599067b-4a80-4174-add0-b1849e7f6088 8. [2 marks] In the FB Emotional Contagion experiment, people in the {'source': 'rag_text.txt'}
# e3054a3b-f2e2-45a3-81a2-6dee2e9c60f1 people in the positivity-reduced {'source': 'rag_text.txt'}
# 1a0c3a97-82ba-48f5-bb9d-fd500920b79f group used _____ positive words and ______ negative words relative to the {'source': 'rag_text.txt'}
# 58838aeb-f581-4963-b3de-09775e1c2d75 to the control group {'source': 'rag_text.txt'}
# fe571ac3-e1e1-458c-b852-c6cdd949ce44 9. [2 marks] What are the three types of validity in social data research? {'source': 'rag_text.txt'}
# f43b635f-3473-4b69-9dd7-c1684a01ed3b data research? {'source': 'rag_text.txt'}
# 123548d1-36e7-49ee-b715-3833db3940e7 10. [1 mark] Consider an experiment where a researcher measures the {'source': 'rag_text.txt'}
# 532a6cdc-3088-4ba5-b2ba-1f55f0e1eafd measures the anxiety level of users {'source': 'rag_text.txt'}
# 0769f2d6-d128-42d0-a1e7-c60bdce79e70 based on a questionnaire. Sometime later, the researcher realizes that the {'source': 'rag_text.txt'}
# e8ceae75-ad55-47ea-b8a7-287e1dc0f3fd that the questionnaire {'source': 'rag_text.txt'}
# 255e095d-34f4-4999-b484-0b0ff3e4bb67 does not accurately measure anxiety levels. What type of research validity {'source': 'rag_text.txt'}
# b8693c0e-4f67-4d30-80a1-1e8d6e12f31c validity is violated in {'source': 'rag_text.txt'}
# a01f42cc-16bf-420f-ae05-d44983acb74f this case? {'source': 'rag_text.txt'}
# a5c37555-8f6d-4998-8bd8-ff5994ebae17 11. [3 marks] What are the three types of bias that arise during social {'source': 'rag_text.txt'}
# 193bd7ce-807b-44db-b3b6-1bc89e80aab7 during social data collection? {'source': 'rag_text.txt'}

# %%
vectorstore.save_local('faiss_index')
new_store = FAISS.load_local('faiss_index', embeddings, allow_dangerous_deserialization=True)

# %%
retrived_docs = vectorstore.similarity_search_with_score('what is the maximum marks?', k=2)
for result, distance_score in retrived_docs:
    print(result.page_content, distance_score)
# Out:
# Maximum Marks = 30 (+6 bonus) 0.45995128
# 6. [1 mark] The density histogram of the number of questions answered by 0.6970546

# %%
retriever = vectorstore.as_retriever(search_kwargs={'k': 3})
docs = retriever.invoke('what is the maximum marks?')
for result in docs:
    print(result.page_content)
# Out:
# Maximum Marks = 30 (+6 bonus)
# 6. [1 mark] The density histogram of the number of questions answered by
# 2. [1 mark] What strategy can be used to determine the required sample

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

template = """
Use the following context to answer the question. Make the answer precise
context: {context}

question: {question}

answer:
"""

prompt = ChatPromptTemplate.from_template(template)

def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)

rag_chain = (
    {'context': retriever | format_docs, 'question': RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

query = 'what is the maximum marks?'
response = rag_chain.invoke(query)
display(Markdown(response))
# Out:
# The maximum marks for the assessment are **30 marks** (with an additional **6 bonus marks** that can be earned).
